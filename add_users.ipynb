# %%
import pandas as pd


df = pd.read_csv("posts.tsv", sep="\t")
user_df = pd.read_csv("users.tsv", sep="\t")
user_df["Name"] = df["User"].unique()
user_df["Job Title"] = "Test"
user_df["Email"] = "test@broadinstitute.org"
user_df["Department"] = "Department of Test"
user_df.to_csv("users.tsv", sep="\t", index=False)
user_df
# Out:
#                                          Name Job Title  \
# 0                                       User1      Test
# 1                             Kenneth P Olive      Test
# 2                              Daniel Herranz      Test
# 3                     Francisco Garcia-Garcia      Test
# 4                              Makenzy L Mull      Test
# ..                                        ...       ...
# 131                              Simon Kozlov      Test
# 132                         Matthew McPartlon      Test
# 133                              Joshua Meier      Test
# 134  Owen Queen, Yepeng Huang, Marinka Zitnik      Test
# 135                            Marinka Zitnik      Test
#
#                        Email          Department Profile Picture  Bio  \
# 0    test@broadinstitute.org  Department of Test             NaN  NaN
# 1    test@broadinstitute.org  Department of Test             NaN  NaN
# 2    test@broadinstitute.org  Department of Test             NaN  NaN
# ...
