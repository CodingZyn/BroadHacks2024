# %%
import datetime
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

df_list = []
for season in ["fall", "spring"]:
    for year in range(2010, 2025):
        url_base = "https://www.broadinstitute.org"
        url = f"{url_base}/talks/{season}-{year}/mia"
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to get {url}")
            continue
        soup = BeautifulSoup(response.text, "html.parser")

        talks = []
        row = 0
        for link in soup.find_all("td", {'headers': re.compile(r'view-.*')}):
            if row == len(talks):
                talks.append({})
            if 'talks-date' in link.get('headers')[0]:
                talks[row]["date"] = link.text.strip()
            elif 'field-speaker' in link.get('headers')[0]:
                talks[row]["speakers"] = [speaker_affil.split("\n\n")[0] for speaker_affil in link.text.strip().split("\n\n\n \n")]
            elif 'title' in link.get('headers')[0]:
                talks[row]["title"] = link.text.strip().rstrip("\n [Video]")
                talks[row]["link"] = url_base + link.find("a").get("href")
                row += 1

        df = pd.DataFrame(talks)

        def get_abstract(link):
            response = requests.get(link)
            soup = BeautifulSoup(response.text, "html.parser")
            abstract = soup.find("div", class_="block block-layout-builder block-field-blocknodetalksbody")
            if abstract is not None:
                return abstract.text.strip()
            else:
                return None

        df["abstract"] = df["link"].apply(get_abstract)
        df["date"] = pd.to_datetime(df["date"], format="%b %d")
        df["date"] = df["date"].apply(lambda x: x.replace(year=year))
        df_list.append(df)

df = pd.concat(df_list)
df = df.sort_values("date")
df
# Out:
# Failed to get https://www.broadinstitute.org/talks/fall-2010/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2011/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2012/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2013/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2014/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2015/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2016/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2017/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2018/mia
# Failed to get https://www.broadinstitute.org/talks/fall-2024/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2010/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2011/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2012/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2013/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2014/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2015/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2016/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2017/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2018/mia
# Failed to get https://www.broadinstitute.org/talks/spring-2019/mia
#          date                                           speakers  \
# 0  2019-02-14                                     [Pascal Notin]
# 1  2019-02-14                   [Noor Youssef, Sarah Faye Gurev]
# 2  2019-03-06  [Sandeep Kambhampati, Philipp Schneider, Kai C...
# 3  2019-03-13                                       [Žiga Avsec]
# 4  2019-03-13                                        [Jun Cheng]
# ..        ...                                                ...
# 12 2024-05-01                                     [Simon Kozlov]
# 13 2024-05-08                                [Matthew McPartlon]
# 14 2024-05-08                                     [Joshua Meier]
# 15 2024-05-29                                   [Marinka Zitnik]
# 16 2024-05-29         [Owen Queen, Yepeng Huang, Marinka Zitnik]
#
#                                                 title  \
# 0   Hybrid protein language models for fitness pre...
# 1   Unsupervised viral antibody escape prediction ...
# 2                                 Postdoc flash talks
# 3   Accurate proteome-wide missense variant effect...
# 4                                       Alpha Missens
# ..                                                ...
# 12  Combining protein language and structure model...
# 13  Protein Design with Deep Learning: Progress, C...
# 14  Unlocking Generative AI for Drug Discovery wit...
# 15  Geometric deep learning and generative models ...
# 16  Multimodal protein language models for deciphe...
#
#                                                  link  \
# 0   https://www.broadinstitute.org/talks/fitness-m...
# 1   https://www.broadinstitute.org/talks/using-pas...
# 2   https://www.broadinstitute.org/talks/postdoc-f...
# 3   https://www.broadinstitute.org/talks/alpha-mis...
# 4   https://www.broadinstitute.org/talks/alpha-mis...
# ..                                                ...
# 12  https://www.broadinstitute.org/talks/combining...
# 13  https://www.broadinstitute.org/talks/protein-d...
# 14        https://www.broadinstitute.org/talks/tbd-10
# 15         https://www.broadinstitute.org/talks/tbd-7
# 16  https://www.broadinstitute.org/talks/multimoda...
#
#                                              abstract
# 0   The ability to accurately model the fitness la...
# 1   Effective pandemic preparedness relies on pred...
# 2                                                None
# 3   The vast majority of missense variants observe...
# 4   The vast majority of missense variants observe...
# ..                                                ...
# 12  All known organisms need all 20 canonical amin...
# 13  The human proteome comprises tens of thousands...
# 14  Generative AI has the potential to greatly inc...
# 15  Computational therapeutic target discovery req...
# 16  Understanding the relationship between a prote...
#
# [170 rows x 5 columns]

# %%
# attributes we need: title, description, keywords, dataset type, collection period, organism, genes, tissue/cell type, condition, technique, instrument platform, software, usage restrictions, related datasets
# use LLM to extract these attributes from the title, abstract, and keywords

from keybert import KeyBERT

model = KeyBERT('distilbert-base-nli-mean-tokens')

def extract_keywords(text):
    keywords = model.extract_keywords(text)
    # remove confidence
    keywords = [keyword[0] for keyword in keywords]
    return keywords

# extract attributes from the title, abstract, and keywords
df = df.dropna(subset="abstract")
df["title_attributes"] = df["title"].apply(extract_keywords)
df["abstract_attributes"] = df["abstract"].apply(extract_keywords)
df
# Out:
# /var/folders/s1/dvr248qn2z75dnpn1zx33xp00000gp/T/ipykernel_89292/2477152345.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["title_attributes"] = df["title"].apply(extract_keywords)
# /var/folders/s1/dvr248qn2z75dnpn1zx33xp00000gp/T/ipykernel_89292/2477152345.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["abstract_attributes"] = df["abstract"].apply(extract_keywords)
#          date                                    speakers  \
# 0  2019-02-14                              [Pascal Notin]
# 1  2019-02-14            [Noor Youssef, Sarah Faye Gurev]
# 3  2019-03-13                                [Žiga Avsec]
# 4  2019-03-13                                 [Jun Cheng]
# 5  2019-03-20                                [Yiqun Chen]
# ..        ...                                         ...
# 12 2024-05-01                              [Simon Kozlov]
# 13 2024-05-08                         [Matthew McPartlon]
# 14 2024-05-08                              [Joshua Meier]
# 15 2024-05-29                            [Marinka Zitnik]
# 16 2024-05-29  [Owen Queen, Yepeng Huang, Marinka Zitnik]
#
#                                                 title  \
# 0   Hybrid protein language models for fitness pre...
# 1   Unsupervised viral antibody escape prediction ...
# 3   Accurate proteome-wide missense variant effect...
# 4                                       Alpha Missens
# 5      Testing data-driven hypotheses post-clustering
# ..                                                ...
# 12  Combining protein language and structure model...
# 13  Protein Design with Deep Learning: Progress, C...
# 14  Unlocking Generative AI for Drug Discovery wit...
# 15  Geometric deep learning and generative models ...
# 16  Multimodal protein language models for deciphe...
#
#                                                  link  \
# 0   https://www.broadinstitute.org/talks/fitness-m...
# 1   https://www.broadinstitute.org/talks/using-pas...
# 3   https://www.broadinstitute.org/talks/alpha-mis...
# 4   https://www.broadinstitute.org/talks/alpha-mis...
# 5   https://www.broadinstitute.org/talks/valid-hyp...
# ..                                                ...
# 12  https://www.broadinstitute.org/talks/combining...
# 13  https://www.broadinstitute.org/talks/protein-d...
# 14        https://www.broadinstitute.org/talks/tbd-10
# 15         https://www.broadinstitute.org/talks/tbd-7
# 16  https://www.broadinstitute.org/talks/multimoda...
#
#                                              abstract  \
# 0   The ability to accurately model the fitness la...
# 1   Effective pandemic preparedness relies on pred...
# 3   The vast majority of missense variants observe...
# 4   The vast majority of missense variants observe...
# 5   This primer talk is motivated by the practice ...
# ..                                                ...
# 12  All known organisms need all 20 canonical amin...
# 13  The human proteome comprises tens of thousands...
# 14  Generative AI has the potential to greatly inc...
# 15  Computational therapeutic target discovery req...
# 16  Understanding the relationship between a prote...
#
#                                      title_attributes  \
# 0      [protein, prediction, fitness, design, hybrid]
# 1     [vaccines, antibody, viral, future, prediction]
# 3   [prediction, accurate, proteome, alpha, missense]
# 4                                    [missens, alpha]
# 5       [hypotheses, testing, clustering, data, post]
# ..                                                ...
# 12         [coli, protein, redesign, amino, alphabet]
# 13      [protein, learning, design, deep, challenges]
# 14   [unlocking, drug, discovery, generative, models]
# 15  [protein, learning, discovery, generative, geo...
# 16  [protein, language, function, multimodal, deci...
#
#                                   abstract_attributes
# 0   [biotherapeutic, hard, massive, proteins, fitn...
# 1   [vaccines, vaccine, viruses, antibodies, antib...
# 3   [genetic, pathogenicity, pathogenic, genes, ge...
# 4   [genetic, pathogenicity, pathogenic, genes, ge...
# 5     [biomedical, researchers, research, genes, rna]
# ..                                                ...
# 12            [coli, proteinmpnn, genes, 20, protein]
# 13  [proteins, protein, evolutionary, evolution, p...
# 14  [libraries, drug, learning, intensive, screening]
# 15  [biology, biomolecular, oncology, proteins, pr...
# 16  [biomedical, proteins, protein, molecular, sci...
#
# [160 rows x 7 columns]

# %%
df_dropped = df.copy()
df_dropped["Title"] = df["title"]
df_dropped["Description"] = df["abstract"].replace(r"\n", " ", regex=True)
df_dropped["Keywords"] = (df["title_attributes"] + df["abstract_attributes"]).apply(lambda x: " ".join(list(set(word.replace(" ", "_") for word in x))) + " mia meeting")
df_dropped["Dataset Type"] = ""
df_dropped["Collection Period"] = df["date"].astype(str)
df_dropped["Organism"] = ""
df_dropped["Genes"] = ""
df_dropped["Tissue/Cell Type"] = ""
df_dropped["Condition"] = ""
df_dropped["Technique"] = ""
df_dropped["Instrument Platform"] = ""
df_dropped["Software"] = ""
df_dropped["Usage Restrictions"] = ""
df_dropped["Related Datasets"] = ""
df_dropped = df_dropped[['Title', 'Description', 'Keywords', 'Dataset Type', 'Collection Period', 'Organism', 'Genes', 'Tissue/Cell Type', 'Condition', 'Technique', 'Instrument Platform', 'Software', 'Usage Restrictions', 'Related Datasets']]
df_dropped
# Out:
#                                                 Title  \
# 0   Hybrid protein language models for fitness pre...
# 1   Unsupervised viral antibody escape prediction ...
# 3   Accurate proteome-wide missense variant effect...
# 4                                       Alpha Missens
# 5      Testing data-driven hypotheses post-clustering
# ..                                                ...
# 12  Combining protein language and structure model...
# 13  Protein Design with Deep Learning: Progress, C...
# 14  Unlocking Generative AI for Drug Discovery wit...
# 15  Geometric deep learning and generative models ...
# 16  Multimodal protein language models for deciphe...
#
#                                           Description  \
# 0   The ability to accurately model the fitness la...
# 1   Effective pandemic preparedness relies on pred...
# 3   The vast majority of missense variants observe...
# 4   The vast majority of missense variants observe...
# 5   This primer talk is motivated by the practice ...
# ..                                                ...
# 12  All known organisms need all 20 canonical amin...
# 13  The human proteome comprises tens of thousands...
# 14  Generative AI has the potential to greatly inc...
# 15  Computational therapeutic target discovery req...
# 16  Understanding the relationship between a prote...
#
#                                              Keywords Dataset Type  \
# 0   biotherapeutic fitness hybrid protein design p...
# 1   antibodies viruses future vaccine prediction a...
# 3   proteome genes genome alpha missense accurate ...
# 4   genes genome alpha missens genetic pathogenici...
# 5   genes data research post biomedical researcher...
# ..                                                ...          ...
# 12  genes amino protein proteinmpnn coli redesign ...
# 13  proteome protein challenges deep design protei...
# 14  intensive learning unlocking screening models ...
# 15  oncology protein learning biology biomolecular...
# 16  function scientists deciphering protein biomed...
#
#    Collection Period Organism Genes Tissue/Cell Type Condition Technique  \
# 0         2019-02-14
# 1         2019-02-14
# 3         2019-03-13
# 4         2019-03-13
# 5         2019-03-20
# ..               ...      ...   ...              ...       ...       ...
# 12        2024-05-01
# 13        2024-05-08
# 14        2024-05-08
# 15        2024-05-29
# 16        2024-05-29
#
#    Instrument Platform Software Usage Restrictions Related Datasets
# 0
# 1
# 3
# 4
# 5
# ..                 ...      ...                ...              ...
# 12
# 13
# 14
# 15
# 16
#
# [160 rows x 14 columns]

# %%
df_dropped.to_csv("mia_talks.csv", index=False)

# %%
df_dropped["Filename"] = ""
df_dropped["User"] = df["speakers"].apply(lambda x: ", ".join(x))
df_dropped["Post ID"] = df_dropped.index + len(pd.read_csv("posts.tsv", sep="\t")) + 1
df_dropped["Likes"] = 0
df_dropped.to_csv("mia_talks_post.tsv", index=False, sep="\t")

# %%
import numpy as np

len(np.unique([keyword for keyword_list in df_dropped["Keywords"].str.split(" ").values for keyword in keyword_list]))
# Out:
# 101
