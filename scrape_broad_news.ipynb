# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime
import pandas as pd
from tqdm.auto import tqdm
import re

page = 0
stop_articles = 100
all_articles = []
urls_visited = set()

pbar = tqdm(total=stop_articles)
while True:
    url = f"https://www.broadinstitute.org/news?page={page}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.find_all("a", href=True)

    for article in articles:
        if article["href"].startswith("/news/"):
            url = f"https://www.broadinstitute.org{article['href']}"
            if url in urls_visited:
                continue
            urls_visited.add(url)
            response = requests.get(url)
            soup = BeautifulSoup(response.content, "html.parser")
            title = soup.find("div", class_="hero-section__title").span.h1.text
            author = soup.find("div", class_="hero-section__author").div.text
            date = datetime.strptime(soup.find("div", class_="hero-section__date").find("time").get("datetime"), "%Y-%m-%dT%H:%M:%S%z").strftime("%Y-%m-%d")
            try:
                article = soup.find("div", {"class": re.compile(r"clearfix text-formatted field field--name-field-text field--type-text-long field--label-hidden field__item")})
                all_articles.append({"title": title, "author": author, "date": date, "article": article.text})
                pbar.update(1)
            except Exception as e:
                texts = soup.find_all("div", {"class": re.compile(r"clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item")})
                for text in texts:
                    if text.find("div", class_="summary-only") is None:
                        all_articles.append({"title": title.strip(), "author": author.strip(), "date": date, "article": text.text.strip()})
                        pbar.update(1)
                        break

    page += 1
    if len(all_articles) >= stop_articles:
        break

df = pd.DataFrame(all_articles)
df
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#                                                  title  \
# 0    A therapy candidate for fatal prion diseases t...
# 1    Simple test for flu could improve diagnosis an...
# 2    Gut microbiome changes align with increased ri...
# 3    #WhyIScience Q&A: A biochemist uses mass spect...
# 4    Improved prime editing system makes gene-sized...
# ..                                                 ...
# 98   Alumni of the Broad’s summer research programs...
# 99   Broad’s summer research programs for high scho...
# 100  Cells can use uridine, a component of RNA, as ...
# 101  Viruses in the guts of centenarians may help t...
# 102  How one lab uses machine learning to solve a k...
#
#                                                 author        date  \
# 0    \n  \n    \n      By Greta Friar, Whitehead In...  2024-06-27
# 1        \n  \n    \n      By Allessandra DiCorato\n    2024-06-18
# 2    \n  \n    \n      By Jennifer Welsh, Brigham a...  2024-06-25
# 3       \n  \n    \n      By Claire Hendershot\r\n\n    2024-06-11
# 4        \n  \n    \n      By Allessandra DiCorato\n    2024-06-10
# ..                                                 ...         ...
# 98   \n  \n    \n      By Broad Communications\r\n\n    2023-05-24
# 99       \n  \n    \n      By Allessandra DiCorato\n    2023-05-24
# 100      \n  \n    \n      By Allessandra DiCorato\n    2023-05-17
# 101      \n  \n    \n      By Allessandra DiCorato\n    2023-05-15
# 102          \n  \n    \n      By Alex Viveros\r\n\n    2023-05-08
#
#                                                article
# 0    Prion diseases lead to rapid neurodegeneration...
# 1    Fewer than one percent of people who get the f...
# 2    The largest and most ethnically and geographic...
# 3    When Moe Haines first moved from Beirut, Leban...
# 4    Scientists at the Broad Institute of MIT and H...
# ..                                                 ...
# 98   The alumni of the Broad Institute’s summer res...
# 99   High school junior Michelle Mantilla was ready...
# 100  Our bodies burn carbohydrates, proteins, and f...
# 101  New research suggests that centenarians — peop...
# 102  When Ben Deverman joined the Broad Institute o...
#
# [103 rows x 4 columns]

# %%
# attributes we need: title, description, keywords, dataset type, collection period, organism, genes, tissue/cell type, condition, technique, instrument platform, software, usage restrictions, related datasets
# use LLM to extract these attributes from the title, abstract, and keywords

from keybert import KeyBERT

model = KeyBERT('distilbert-base-nli-mean-tokens')

def extract_keywords(text):
    keywords = model.extract_keywords(text)
    # remove confidence
    keywords = [keyword[0] for keyword in keywords]
    return keywords

# extract attributes from the title, abstract, and keywords
df = df.dropna(subset="article")
df["title_attributes"] = df["title"].apply(extract_keywords)
df["article_attributes"] = df["article"].apply(extract_keywords)
df
# Out:
#                                                  title  \
# 0    A therapy candidate for fatal prion diseases t...
# 1    Simple test for flu could improve diagnosis an...
# 2    Gut microbiome changes align with increased ri...
# 3    #WhyIScience Q&A: A biochemist uses mass spect...
# 4    Improved prime editing system makes gene-sized...
# ..                                                 ...
# 98   Alumni of the Broad’s summer research programs...
# 99   Broad’s summer research programs for high scho...
# 100  Cells can use uridine, a component of RNA, as ...
# 101  Viruses in the guts of centenarians may help t...
# 102  How one lab uses machine learning to solve a k...
#
#                                                 author        date  \
# 0    \n  \n    \n      By Greta Friar, Whitehead In...  2024-06-27
# 1        \n  \n    \n      By Allessandra DiCorato\n    2024-06-18
# 2    \n  \n    \n      By Jennifer Welsh, Brigham a...  2024-06-25
# 3       \n  \n    \n      By Claire Hendershot\r\n\n    2024-06-11
# 4        \n  \n    \n      By Allessandra DiCorato\n    2024-06-10
# ..                                                 ...         ...
# 98   \n  \n    \n      By Broad Communications\r\n\n    2023-05-24
# 99       \n  \n    \n      By Allessandra DiCorato\n    2023-05-24
# 100      \n  \n    \n      By Allessandra DiCorato\n    2023-05-17
# 101      \n  \n    \n      By Allessandra DiCorato\n    2023-05-15
# 102          \n  \n    \n      By Alex Viveros\r\n\n    2023-05-08
#
#                                                article  \
# 0    Prion diseases lead to rapid neurodegeneration...
# 1    Fewer than one percent of people who get the f...
# 2    The largest and most ethnically and geographic...
# 3    When Moe Haines first moved from Beirut, Leban...
# 4    Scientists at the Broad Institute of MIT and H...
# ..                                                 ...
# 98   The alumni of the Broad Institute’s summer res...
# 99   High school junior Michelle Mantilla was ready...
# 100  Our bodies burn carbohydrates, proteins, and f...
# 101  New research suggests that centenarians — peop...
# 102  When Ben Deverman joined the Broad Institute o...
#
#                                       title_attributes  \
# 0       [therapy, disease, diseases, fatal, candidate]
# 1        [flu, surveillance, diagnosis, improve, test]
# 2     [diabetes, microbiome, increased, changes, risk]
# 3    [biochemist, cancer, spectrometry, proteins, m...
# 4        [therapeutic, improved, editing, edits, gene]
# ..                                                 ...
# 98   [alumni, professional, summer, personal, resea...
# 99        [scientists, students, summer, college, 300]
# 100           [rna, uridine, cells, energy, component]
# 101     [viruses, pathogens, help, centenarians, guts]
# 102            [lab, therapy, learning, gene, machine]
#
#                                     article_attributes
# 0    [neurodegenerative, neurodegeneration, scienti...
# 1    [influenza, influenzas, scientists, clinicians...
# 2    [diabetes, bacteriophages, probiotics, genetic...
# 3    [biochemistry, startup, biology, genomics, pha...
# 4    [biotech, biomedical, scientists, harvard, med...
# ..                                                 ...
# 98   [scientists, alumni, universities, scholars, s...
# 99   [harvard, biology, diabetes, scientists, mexican]
# 100          [diabetes, cancer, cancers, obesity, atp]
# 101  [microbiology, bacteria, bacteriophages, immun...
# 102              [harvard, caltech, viral, virus, lab]
#
# [103 rows x 6 columns]

# %%
df_dropped = df.copy()
df_dropped["Title"] = df["title"]
df_dropped["Description"] = df["article"].replace(r"\n", " ", regex=True).replace(r"\s+", " ", regex=True)
df_dropped["Keywords"] = (df["title_attributes"] + df["article_attributes"]).apply(lambda x: " ".join(list(set(word.replace(" ", "_") for word in x))) + " broad news")
df_dropped["Dataset Type"] = ""
df_dropped["Collection Period"] = df["date"].astype(str)
df_dropped["Organism"] = ""
df_dropped["Genes"] = ""
df_dropped["Tissue/Cell Type"] = ""
df_dropped["Condition"] = ""
df_dropped["Technique"] = ""
df_dropped["Instrument Platform"] = ""
df_dropped["Software"] = ""
df_dropped["Usage Restrictions"] = ""
df_dropped["Related Datasets"] = ""
df_dropped = df_dropped[['Title', 'Description', 'Keywords', 'Dataset Type', 'Collection Period', 'Organism', 'Genes', 'Tissue/Cell Type', 'Condition', 'Technique', 'Instrument Platform', 'Software', 'Usage Restrictions', 'Related Datasets']]
df_dropped
# Out:
#                                                  Title  \
# 0    A therapy candidate for fatal prion diseases t...
# 1    Simple test for flu could improve diagnosis an...
# 2    Gut microbiome changes align with increased ri...
# 3    #WhyIScience Q&A: A biochemist uses mass spect...
# 4    Improved prime editing system makes gene-sized...
# ..                                                 ...
# 98   Alumni of the Broad’s summer research programs...
# 99   Broad’s summer research programs for high scho...
# 100  Cells can use uridine, a component of RNA, as ...
# 101  Viruses in the guts of centenarians may help t...
# 102  How one lab uses machine learning to solve a k...
#
#                                            Description  \
# 0    Prion diseases lead to rapid neurodegeneration...
# 1    Fewer than one percent of people who get the f...
# 2    The largest and most ethnically and geographic...
# 3    When Moe Haines first moved from Beirut, Leban...
# 4    Scientists at the Broad Institute of MIT and H...
# ..                                                 ...
# 98   The alumni of the Broad Institute’s summer res...
# 99   High school junior Michelle Mantilla was ready...
# 100  Our bodies burn carbohydrates, proteins, and f...
# 101  New research suggests that centenarians — peop...
# 102  When Ben Deverman joined the Broad Institute o...
#
#                                               Keywords Dataset Type  \
# 0    candidate neurodegenerative diseases fatal bio...
# 1    influenza diagnosis improve influenzas surveil...
# 2    increased bacteria microbiome diabetes bacteri...
# 3    proteins genomics biology spectrometry cancer ...
# 4    edits therapeutic editing gene biotech medicin...
# ..                                                 ...          ...
# 98   research professional alumni summer scholars s...
# 99   college biology 300 summer harvard students di...
# 100  cancers cells rna cancer obesity diabetes atp ...
# 101  immunology viruses help pathogens bacteria bac...
# 102  gene lab machine viral learning harvard therap...
#
#     Collection Period Organism Genes Tissue/Cell Type Condition Technique  \
# 0          2024-06-27
# 1          2024-06-18
# 2          2024-06-25
# 3          2024-06-11
# 4          2024-06-10
# ..                ...      ...   ...              ...       ...       ...
# 98         2023-05-24
# 99         2023-05-24
# 100        2023-05-17
# 101        2023-05-15
# 102        2023-05-08
#
#     Instrument Platform Software Usage Restrictions Related Datasets
# 0
# 1
# 2
# 3
# 4
# ..                  ...      ...                ...              ...
# 98
# 99
# 100
# 101
# 102
#
# [103 rows x 14 columns]

# %%
df_dropped.to_csv("broad_newsletter.csv", index=False)

# %%
df_dropped["Filename"] = ""
df_dropped["User"] = df["author"].str.strip().str.replace(r"^\s*By\s+", "", regex=True)
df_dropped["Post ID"] = df_dropped.index + len(pd.read_csv("posts.tsv", sep="\t")) + 1
df_dropped["Likes"] = 0
df_dropped.to_csv("broad_newsletter_post.tsv", index=False, sep="\t")

# %%
import numpy as np

len(np.unique([keyword for keyword_list in df_dropped["Keywords"].str.split(" ").values for keyword in keyword_list]))
# Out:
# 469
